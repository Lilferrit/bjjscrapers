# %%
import polars as pl

data = pl.read_parquet("../data/results.parquet")

# %%
data.filter(pl.col("loser_weight").is_not_null())
# Out:
# shape: (0, 33)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬────────┬───────────┐
# │ data_sourc ┆ is_inferre ┆ tournamen ┆ tournamen ┆ … ┆ loser_med ┆ loser_not ┆ is_bye ┆ is_unfini │
# │ e          ┆ d          ┆ t_id      ┆ t_name    ┆   ┆ al        ┆ e         ┆ ---    ┆ shed      │
# │ ---        ┆ ---        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ bool   ┆ ---       │
# │ str        ┆ bool       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆        ┆ bool      │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪════════╪═══════════╡
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴────────┴───────────┘
